# %% [markdown]
# Import Library

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# Data Gathering

# %%
# Mendefinisikan API key
API_KEY = "AIzaSyCJ6IVTL7ro6YCdzSPdV8QeUWYr8a4Ptss"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

from googleapiclient.discovery import build
import pandas as pd

# Fungsi untuk mengumpulkan komentar dari video YouTube
def get_video_comments(video_id):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=API_KEY)
    comments = []

    # Mengoleksi komentar
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100
    )

    # Mengoleksi komentar serta pengunggah komentar
    while request:
        response = request.execute()
        for item in response["items"]:
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                "author": comment["authorDisplayName"],
                "comment": comment["textDisplay"],
                "likes": comment["likeCount"]  # Menambahkan jumlah like
            })
        request = youtube.commentThreads().list_next(request, response)
    return comments

# Fungsi untuk menyimpan komentar ke dalam file CSV
def save_comments_to_csv(comments, filename):
    data = pd.DataFrame(comments)
    data.to_csv(filename, index=False)

if __name__ == "__main__":
    # Daftar ID video dari link yang diberikan
    video_ids = [
        "xOg20MgYZTY",  # Link: https://youtu.be/xOg20MgYZTY
        "8Assb2RwAJA",  # Link: https://youtu.be/8Assb2RwAJA
        "eFDgYSKk3KU",  # Link: https://youtu.be/eFDgYSKk3KU
        "2u5ILxoxAvA",  # Link: https://youtu.be/2u5ILxoxAvA
        "YKrqTHNymAk",  # Link: https://youtu.be/YKrqTHNymAk
        "ItJUNk0eVNo"   # Link: https://youtu.be/ItJUNk0eVNo
    ]
    all_comments = []

    # Melakukan iterasi untuk mendapatkan komentar dari setiap video
    for i, video_id in enumerate(video_ids):
        print(f"Sedang mengumpulkan komentar dari video {i+1}/{len(video_ids)}: {video_id}")
        comments = get_video_comments(video_id)
        all_comments.extend(comments)

    # Menyimpan semua komentar ke dalam file csv
    save_comments_to_csv(all_comments, "komentar_youtube_dms.csv")
    print("Berhasil! Seluruh komentar telah berhasil tersimpan.")
# Out:
# Sedang mengumpulkan komentar dari video 1/6: xOg20MgYZTY
# Sedang mengumpulkan komentar dari video 2/6: 8Assb2RwAJA
# Sedang mengumpulkan komentar dari video 3/6: eFDgYSKk3KU
# Sedang mengumpulkan komentar dari video 4/6: 2u5ILxoxAvA
# Sedang mengumpulkan komentar dari video 5/6: YKrqTHNymAk
# Sedang mengumpulkan komentar dari video 6/6: ItJUNk0eVNo
# Berhasil! Seluruh komentar telah berhasil tersimpan.

# %%
# Menampilkan 10 baris pertama dari komentar
data = pd.read_csv("komentar_youtube_dms.csv")
data.head(10)
# Out:
#                      author  \
# 0                @mochibull
# 1             @AnisSuci-y7i
# 2            @nurhaliza7192
# 3                @fitri8282
# 4           @GojakGojek-d3e
# 5  @zeusthemobilelegend4165
# 6                @Dai_houyu
# 7    @rizkyrobiatinnisa9941
# 8        @irmawulandari9148
# 9               @Rohaniflog
#
#                                              comment  likes
# 0  Merinding nya kerasa sampe sini brook, geloo, ...      0
# 1  Saya orang Surabaya saya sering lewat rumah in...      0
# 2         nungguin yang di kalisosok nya kapan nyai😭      0
# 3                           duet sm ghost ranger kak      0
# 4  Kesini gara gara pesulap merah singgung inisia...      0
# 5  Siapa yg setuju mbak sarah kolaborasi sama ki ...      0
# 6  Sumpah episode kali ini mual banget pengen mun...      0
# 7  haaaa gilaaa penasaran bgt apaan sih ibunya ma...      0
# 8  Saya download app dmsplus di tv android. Masuk...      0
# ...

# %% [markdown]
# Data Assessing

# %%
# Menampilkan 10 baris pertama dari data awal
print("10 Baris Pertama dari Data Awal:")
print(data.head(10))

# Data Assessing
print("\n# Data Assessing\n")

# Menampilkan ukuran data (jumlah baris dan kolom)
print("Ukuran Data (Sebelum Cleaning):")
print(data.shape)

# Menampilkan informasi awal terkait data
print("\nInformasi Data (Sebelum Cleaning):")
print(data.info())

# Menghitung missing values untuk setiap kolom
print("\nJumlah Missing Values (Sebelum Cleaning):")
print(data.isnull().sum())
# Out:
# 10 Baris Pertama dari Data Awal:
#                      author  \
# 0                @mochibull
# 1             @AnisSuci-y7i
# 2            @nurhaliza7192
# 3                @fitri8282
# 4           @GojakGojek-d3e
# 5  @zeusthemobilelegend4165
# 6                @Dai_houyu
# 7    @rizkyrobiatinnisa9941
# 8        @irmawulandari9148
# 9               @Rohaniflog
#
#                                              comment  likes
# 0  Merinding nya kerasa sampe sini brook, geloo, ...      0
# 1  Saya orang Surabaya saya sering lewat rumah in...      0
# 2         nungguin yang di kalisosok nya kapan nyai😭      0
# 3                           duet sm ghost ranger kak      0
# 4  Kesini gara gara pesulap merah singgung inisia...      0
# 5  Siapa yg setuju mbak sarah kolaborasi sama ki ...      0
# 6  Sumpah episode kali ini mual banget pengen mun...      0
# 7  haaaa gilaaa penasaran bgt apaan sih ibunya ma...      0
# 8  Saya download app dmsplus di tv android. Masuk...      0
# ...

# %% [markdown]
# Data Cleaning

# %%
# Data Cleaning
print("\n# Data Cleaning\n")

# Menghapus missing values
data_cleaned = data.dropna()
print("Jumlah Data Setelah Menghapus Missing Values:")
print(data_cleaned.shape)

# Menghapus data duplikat
data_cleaned.drop_duplicates(inplace=True)
print("\nInformasi Data Setelah Menghapus Duplikat:")
print(data_cleaned.info())

# Menampilkan 10 baris pertama setelah data dibersihkan
print("\n10 Baris Pertama dari Data Setelah Cleaning:")
print(data_cleaned.head(10))
# Out:
# # Data Cleaning
#
# Jumlah Data Setelah Menghapus Missing Values:
# (22072, 3)
#
# Informasi Data Setelah Menghapus Duplikat:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21792 entries, 0 to 22072
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   author   21792 non-null  object
#  1   comment  21792 non-null  object
#  2   likes    21792 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 681.0+ KB
# None
#
# 10 Baris Pertama dari Data Setelah Cleaning:
#                      author  \
# 0                @mochibull
# 1             @AnisSuci-y7i
# 2            @nurhaliza7192
# 3                @fitri8282
# 4           @GojakGojek-d3e
# 5  @zeusthemobilelegend4165
# 6                @Dai_houyu
# 7    @rizkyrobiatinnisa9941
# 8        @irmawulandari9148
# 9               @Rohaniflog
#
#                                              comment  likes
# 0  Merinding nya kerasa sampe sini brook, geloo, ...      0
# ...
